# %%
from random import random
import matplotlib.pyplot as plt
import numpy as np

Points = []
stretch = 3

for idx in range(5):
    for _ in range(300):
        Points.append(stretch * ((2-idx) + random(),stretch * (2 - idx) + random()))
    
Points = np.array(Points)

plt.scatter(Points[:,0], Points[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans, DBSCAN

# %%
kmeans_model = KMeans(n_clusters=3)
y_pred = kmeans_model.fit_predict(Points)

plt.scatter(Points[:, 0], Points[:, 1], c=y_pred)
plt.show()

# %%
db = DBSCAN(eps=1, min_samples=20).fit(Points)

core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 5
# Estimated number of noise points: 0

# %%
plt.scatter(Points[:, 0], Points[:, 1], c=db.labels_)
plt.show()
